# %% [markdown]
# # Getting the list of sofwares in Data Mining Category

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re 
import pandas as pd
import json 
import csv 
from urllib.parse import urljoin
import time
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Dabu bahya\Downloads\Desktop\Review-Analysis\product_list.csv')
df.head()
# Out:
#    Unnamed: 0                  Product Name                 Category  \
# 0           0                 Spider Impact  data analysis software
# 1           1                Zoho Analytics  data analysis software
# 2           2                        Cluvio  data analysis software
# 3           3  Minitab Statistical Software  data analysis software
# 4           4                     Hexowatch  data analysis software
#
#          Company Name                               URL to Capterra Page
# 0   Spider Strategies              www.capterra.com/p/113352/Scoreboard/
# 1                Zoho          www.capterra.com/p/129749/Zoho-Analytics/
# 2              Cluvio                  www.capterra.com/p/162332/Cluvio/
# 3             Minitab  www.capterra.com/p/109731/Minitab-Statistical-...
# 4              Hexact               www.capterra.com/p/206900/Hexowatch/

# %%
new_df = df.query('`Category`.str.startswith("data mining")')
new_df
# Out:
#      Unnamed: 0                Product Name               Category  \
# 581         581        Batch Data Collector  data mining software
# 582         582                        SPSS  data mining software
# 583         583         Wolfram Mathematica  data mining software
# 584         584                   Octoparse  data mining software
# 585         585                     Mozenda  data mining software
# 586         586                  RapidMiner  data mining software
# 587         587        SAS Enterprise Miner  data mining software
# 588         588                      Orange  data mining software
# 589         589             Neural Designer  data mining software
# 590         590            Apteco FastStats  data mining software
# 591         591                    uCrawler  data mining software
# 592         592          Oracle Data Mining  data mining software
# 593         593                  AlertMiner  data mining software
# 594         594                   limestats  data mining software
# 595         595                     Pitchly  data mining software
# 596         596                 PolyAnalyst  data mining software
# 597         597      Coheris Analytics SPAD  data mining software
# 598         598             Data.Mining.Fox  data mining software
# 599         599    eccenca Corporate Memory  data mining software
# 600         600               EntelliFusion  data mining software
# 601         601                  ExportData  data mining software
# 602         602                      FS.net  data mining software
# 603         603                        Keel  data mining software
# 604         604                     Ketrium  data mining software
# 605         605                    Optymyze  data mining software
# 606         606                      Piperr  data mining software
# 607         607                   PoolParty  data mining software
# 608         608                   Repustate  data mining software
# 609         609  Salford Predictive Modeler  data mining software
# 610         610                        Seeq  data mining software
# 611         611                   Semantria  data mining software
# 612         612                  SyncSpider  data mining software
# 613         613     Text Analytics Platform  data mining software
# 614         614                     XLMiner  data mining software
#
#                  Company Name  \
# 581      Batch Data Collector
# 582                       IBM
# 583                   Wolfram
# 584              Octopus Data
# 585                   Mozenda
# 586                RapidMiner
# 587             SAS Institute
# 588   University of Ljubljana
# 589                 Artelnics
# 590                    Apteco
# 591                  uCrawler
# 592                    Oracle
# 593                 AutoAlert
# 594                 limestats
# 595                   Pitchly
# 596    Megaputer Intelligence
# 597                   Coheris
# 598          Easy.Data.Mining
# 599                   eccenca
# 600                  Teksouth
# 601                 ZIKU TECH
# 602                  Symbrium
# 603                      Keel
# 604                   Ketrium
# 605                  Optymyze
# 606                   Saturam
# 607      Semantic Web Company
# 608                 Repustate
# 609           Salford Systems
# 610          Seeq Corporation
# 611                Lexalytics
# 612                SyncSpider
# 613                  SetuServ
# 614         Frontline Systems
#
#                                   URL to Capterra Page
# 581  www.capterra.com/p/209952/Batch-Data-Collector...
# 582                     www.capterra.com/p/13990/SPSS/
# 583     www.capterra.com/p/171048/Wolfram-Mathematica/
# 584               www.capterra.com/p/150508/Octoparse/
# 585                 www.capterra.com/p/102193/Mozenda/
# 586              www.capterra.com/p/148220/RapidMiner/
# 587    www.capterra.com/p/157071/SAS-Enterprise-Miner/
# 588                  www.capterra.com/p/164505/Orange/
# 589         www.capterra.com/p/156274/Neural-Designer/
# 590               www.capterra.com/p/101009/FastStats/
# 591                www.capterra.com/p/186866/uCrawler/
# 592      www.capterra.com/p/169949/Oracle-Data-Mining/
# 593              www.capterra.com/p/197068/AlertMiner/
# 594               www.capterra.com/p/178789/limestats/
# 595                 www.capterra.com/p/151099/Pitchly/
# 596             www.capterra.com/p/125821/PolyAnalyst/
# 597  www.capterra.com/p/171508/Coheris-Analytics-SPAD/
# 598         www.capterra.com/p/171506/Data-Mining-Fox/
# 599  www.capterra.com/p/190219/eccenca-Corporate-Me...
# 600           www.capterra.com/p/207622/EntelliFusion/
# 601              www.capterra.com/p/189877/ExportData/
# 602                  www.capterra.com/p/183884/FS-net/
# 603                    www.capterra.com/p/171507/Keel/
# 604                 www.capterra.com/p/187439/Ketrium/
# 605                www.capterra.com/p/137148/Optymyze/
# 606                  www.capterra.com/p/183888/Piperr/
# 607               www.capterra.com/p/171504/PoolParty/
# 608               www.capterra.com/p/201539/Repustate/
# 609                 www.capterra.com/p/169966/SPM-8-2/
# 610                    www.capterra.com/p/171687/Seeq/
# 611               www.capterra.com/p/151930/Semantria/
# 612              www.capterra.com/p/211760/SyncSpider/
# 613  www.capterra.com/p/211552/Text-Analytics-Platf...
# 614                 www.capterra.com/p/151767/XLMiner/

# %%
# We start scraping each product site with time delay of 10s.
start_time = time.time()

for i in range(len(new_df)):
    url =  "https://" + new_df.iloc[i]['URL to Capterra Page']
    p_name = new_df.iloc[i]['Product Name']
    p_category = new_df.iloc[i]['Category']

    if re.match(r"#reviews", url):
        url = re.sub(r"#reviews",'', url)
    else:
        pass
    driver = webdriver.Chrome(r'D:\Downloads\Desktop\chromedriver')  
    driver.get(url)

    soup = BeautifulSoup(driver.page_source,"html.parser" )
    soup_obj = soup.find('div',{'class':'ProductSummary__SummaryPanel-mcm4i7-6 hCwGXf'})

    product = soup_obj.contents[0]
    product_info = product.select('div > div')[0].get_text(strip=True) #this is info about the product 

    #for checking that if "featured in" exists on the site 
    x = soup_obj.contents[1].h2.get_text()

    if re.match(r"Featured In", x):

        c = soup_obj.contents[2]
        y = c.h2.get_text(strip=True)
        if re.match(r"Best For",y):
            d = c.select('div > em')[0].get_text(strip=True) # best for 
            var = 3

        else:
            d = "Not Available"
            var = 2


        try :
            e = soup_obj.contents[var]
            f = e.select('div > p')[0].get_text(strip=True)  # company name
        except:
            f = "Not Available"

        try :
            g = soup_obj.contents[var]
            h = g.select('div > p')[1].get_text(strip=True)  # product website
        except:
            h = "Not Available"  


        i = soup_obj.contents[var]
        j = i.select('div > p')[2].get_text(strip=True)  # founding year
        if not j:
            j = "Not Available"
        else:
            pass  

        k = soup_obj.contents[var]
        l = k.select('div > p')[3].get_text(strip=True)  # founding place
        if not l:
            l = "Not Available"
        else:
            pass

    else:
        c = soup_obj.contents[1]
        y = c.h2.get_text(strip=True)
        if re.match(r"Best For",y):
            d = c.select('div > em')[0].get_text(strip=True)
            var = 2

        else:
            d = "Not Available"
            var = 1


        try :
            e = soup_obj.contents[var]
            f = e.select('div > p')[0].get_text(strip=True)
        except:
            f = "Not Available"

        try :
            g = soup_obj.contents[var]
            h = g.select('div > p')[1].get_text(strip=True)
        except:
            h = "Not Available"

        i = soup_obj.contents[var]
        j = i.select('div > p')[2].get_text(strip=True)
        if not j:
            j = "Not Available"
        else:
            pass

        k = soup_obj.contents[var]
        l = k.select('div > p')[3].get_text(strip=True)
        if not l:
            l = "Not Available"
        else:
            pass
    info = {'About Product': product_info,'Best For':d,'Company Name': f,'Product Website': h, 'Founding Year': j,'Founding Place': l }


    new_soup = soup.find('div',{'class':'SpecTable__Root-sc-1jq5uy4-0 jZHgUG'})
    len_of_new_soup = len(new_soup.contents)
    # the listed price of the product, if given.
    try:
        price_heading = new_soup.contents[0].h3.get_text()
        price = new_soup.contents[0].a.get_text()
        listed_price = {price_heading:price}

    except:
        price_heading = new_soup.contents[0].h3.get_text()
        price = "Not Available"
        listed_price = {price_heading:price}
    # for available features in Deployment, Training,& Support
    ndic ={}
    for i in range(1,len_of_new_soup):
        s_obj = new_soup.contents[i]
        heading = s_obj.h3.get_text()
        new_obj = s_obj.contents[1]
        nl = []
        for i in range(len(new_obj)):
            an_obj = new_obj.contents[i]
            x = an_obj.select('div > div')[0]['class']
            y= x[1]
            if y == 'bqMKDC':
                q = an_obj.select('div > div')[1].get_text(strip=True)
                nl.append(q)

        ndic[heading] =nl



    another_soup_obj = soup.find('div',{'class':'Accordion__Root-sc-1jo79it-0 jGWhUg'})
    # clicking all the buttons 
    for i in range(1,len(another_soup_obj.contents)):
        h4 = another_soup_obj.contents[i].h4.get_text()
        cb = "//button[normalize-space()=" + f'"{h4}"' + "]"
        element = driver.find_element_by_xpath(cb)
        driver.execute_script("arguments[0].click();", element)

    # extracting the corresponding features
    nd = {}
    for i in range(len(another_soup_obj)):
        field_heading = another_soup_obj.contents[i].h4.get_text()
        n_o_j = another_soup_obj.contents[i]
        xyz = n_o_j.find_all('div',{'class':'FeatureList__FeatureCell-sc-1kxeq27-1 ifqTCQ'})
        nl = []
        for i in xyz:
            zas = i.select('div > div')[1]['class']
            sac = zas[1]
            if sac == 'bqMKDC':
                q = i.select('div > div')[2].get_text(strip=True)
                nl.append(q)
        nd[field_heading] = nl



    newurl = urljoin(url,'reviews')
    another_driver = webdriver.Chrome(r'D:\Downloads\Desktop\chromedriver')
    another_driver.get(newurl)

    while True:
        try:
            new_element = another_driver.find_element_by_xpath('//button[normalize-space()="Show more reviews"]')
            another_driver.execute_script("arguments[0].click();", new_element)
        except:
            break

    review_soup = BeautifulSoup(another_driver.page_source,"html.parser" )

    ls = ['Overall','Ease of Use','Customer Service']
    ratings = soup.find_all('div',{'class':'StarRating__Rating-sc-9jwzgg-1 cAGyvf'})
    la = []
    for x,y in zip(ls,ratings):
        la.append({x:y.get_text(strip=True)})


    try:
        start = review_soup.find('div',{'class':'gtm-review-section'})
        perm_list = []

        for i in range(len(start.contents)):
            empty_list = []
        #reviewer info
            qw = start.contents[i]
            personal_info = qw.find('div',{'class':'ReviewerAvatarSection__ReviewerInfo-sc-1a80501-1 cSadMy'})
            name = personal_info.contents[0].get_text(strip=True)
            other_info = personal_info.contents[1]
            designation = other_info.select('div > div')[0].get_text(strip=True)
            working_domain = other_info.select('div > div')[1].get_text(strip=True) 
            usage = other_info.select('div > div')[2].get_text(strip=True)
            reviewer_info = {name:[designation,working_domain,usage]}
            empty_list.append(reviewer_info)

        #reviewer ratings    
            li = ['Overall','Ease of Use','Customer Service', 'Features', ' Value for Money','Likelihood to Recommend']
            ra = qw.find_all('div',{'class':'StarRating__Rating-sc-9jwzgg-1 kCLiav'})
            reviewer_ratings = []
            for x,y in zip(li,ra):
                reviewer_ratings.append({x:y.get_text(strip=True)})
            empty_list.append(reviewer_ratings)

        #date    
            date = qw.find('div',{'class':'ReviewSource__Root-lnjke6-0 iBAGLQ'}).contents[2].get_text(strip=True)
            empty_list.append(date)

        #review

            review = qw.find('div',{'class':'ReviewCard__RightFlexItem-sc-18j15p9-3 cOmWnW ReviewCard__FlexItem-sc-18j15p9-2 bTVfYT'})
            review_heading = review.contents[0].h3.get_text(strip=True)
            overall = review.contents[0].find_all('div',{'class':'ReviewSection__Root-sc-189472c-0 icjcMH'})
            review_text ={}
            review_text['review heading'] = review_heading
            for i in overall :
                text = i.get_text(strip=True)
                manip = text.split(':')
                header = manip[0]
                review_content = manip[1]
                review_text[header] = review_content


            empty_list.append(review_text)
            perm_list.append(empty_list)

        new_dic = {'Product Name': p_name,'Category': p_category, 'Product Info': info , 'Price': listed_price, 'Overall Features': ndic ,'Category Features': nd ,'Overall Ratings': la, 'Review': perm_list}

        other = pd.DataFrame([new_dic])

        with open('data_mining.csv', 'a', encoding='utf8') as f:
            other.to_csv(f, header=f.tell()==0)
    except:
        pass
    another_driver.close()   
    driver.close()
    time.sleep(10)

end_time=time.time()
total_time=end_time-start_time

# %%
print(total_time)
# Out:
# 2031.800500869751

# %%
# We load the data as a dataframe, with forcing pandas to read python datatypes(list,dict) as it is using "eval".
product_review_df = pd.read_csv('data_mining.csv',converters={'Product Info': eval,'Price': eval,'Overall Features': eval,'Category Features': eval,'Overall Ratings': eval,'Review': eval })
product_review_df.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
product_review_df.drop(["a"], axis=1, inplace=True)
product_review_df
# Out:
#             Product Name               Category  \
# 0   Batch Data Collector  data mining software
# 1                Mozenda  data mining software
# 2             RapidMiner  data mining software
# 3   SAS Enterprise Miner  data mining software
# 4                 Orange  data mining software
# 5        Neural Designer  data mining software
# 6       Apteco FastStats  data mining software
# 7               uCrawler  data mining software
# 8     Oracle Data Mining  data mining software
# 9             AlertMiner  data mining software
# 10             limestats  data mining software
# 11               Pitchly  data mining software
# 12           PolyAnalyst  data mining software
#
#                                          Product Info  \
# 0   {'About Product': 'Chrome extension designed t...
# 1   {'About Product': '#1 Web Scraping Software an...
# 2   {'About Product': 'Cloud-based data science pl...
# 3   {'About Product': 'Data mining system that all...
# 4   {'About Product': 'Open-source data visualizat...
# 5   {'About Product': 'Build your neural network p...
# 6   {'About Product': 'ANALYSE -
# Apteco FastStats...
# 7   {'About Product': 'uCrawler automatically extr...
# 8   {'About Product': 'Data mining app that provid...
# 9   {'About Product': 'Tells you which customers a...
# 10  {'About Product': 'Limestats is software that ...
# 11  {'About Product': 'Pitchly organizes and activ...
# 12  {'About Product': 'Megaputer Intelligence is a...
#
#                                   Price  \
# 0   {'Starting Price': 'Not Available'}
# 1   {'Starting Price': 'Not Available'}
# 2   {'Starting Price': 'Not Available'}
# 3   {'Starting Price': 'Not Available'}
# 4   {'Starting Price': 'Not Available'}
# 5   {'Starting Price': 'Not Available'}
# 6   {'Starting Price': 'Not Available'}
# 7   {'Starting Price': 'Not Available'}
# 8   {'Starting Price': 'Not Available'}
# 9   {'Starting Price': 'Not Available'}
# 10  {'Starting Price': 'Not Available'}
# 11  {'Starting Price': 'Not Available'}
# 12  {'Starting Price': 'Not Available'}
#
#                                      Overall Features  \
# 0   {'Free Trial': ['Yes,get a free trial'], 'Depl...
# 1   {'Free Trial': ['Yes'], 'Deployment': ['Instal...
# 2   {'Deployment': ['Installed - Mac', 'Installed ...
# 3   {'Deployment': ['Installed - Windows', 'Web-Ba...
# 4   {'Deployment': ['Installed - Mac', 'Installed ...
# 5   {'Free Trial': ['Yes'], 'Deployment': ['Instal...
# 6   {'Free Trial': ['Yes'], 'Deployment': ['Instal...
# 7   {'Free Trial': ['Yes'], 'Deployment': ['Web-Ba...
# 8                                                  {}
# 9                                                  {}
# 10  {'Deployment': ['Web-Based, Cloud, SaaS'], 'Tr...
# 11  {'Free Trial': ['Yes'], 'Deployment': ['Web-Ba...
# 12  {'Free Trial': ['Yes'], 'Deployment': ['Instal...
#
#                                     Category Features  \
# 0   {'Data Extraction': ['Disparate Data Collectio...
# 1   {'Data Extraction': ['Disparate Data Collectio...
# 2   {'Business Process Management': ['Access Contr...
# 3   {'Data Mining': ['Data Extraction', 'Data Visu...
# 4   {'Data Visualization': ['Analytics/Reporting',...
# 5   {'Data Analysis': ['Data Visualization', 'Pred...
# 6   {'Business Intelligence': ['Ad Hoc Reports', '...
# 7   {'Data Mining': ['Data Extraction', 'Data Visu...
# 8   {'Data Mining': ['Fraud Detection', 'Predictiv...
# 9                                                  {}
# 10  {'Data Mining': ['Data Extraction', 'Data Visu...
# 11  {'Customer Data Platform': ['Data Integration'...
# 12  {'Statistical Analysis': ['Association Discove...
#
#                                       Overall Ratings  \
# 0   [{'Overall': '4.7/5'}, {'Ease of Use': '4.7/5'...
# 1   [{'Overall': '4.7/5'}, {'Ease of Use': '4.7/5'...
# 2   [{'Overall': '4.4/5'}, {'Ease of Use': '4.5/5'...
# 3   [{'Overall': '4.6/5'}, {'Ease of Use': '4.5/5'...
# 4   [{'Overall': '4.5/5'}, {'Ease of Use': '4.4/5'...
# 5   [{'Overall': '4.5/5'}, {'Ease of Use': '4.7/5'...
# 6   [{'Overall': '4.7/5'}, {'Ease of Use': '4.4/5'...
# 7   [{'Overall': '4.6/5'}, {'Ease of Use': '4.5/5'...
# 8   [{'Overall': '4.6/5'}, {'Ease of Use': '4.5/5'...
# 9   [{'Overall': '4.6/5'}, {'Ease of Use': '4.5/5'...
# 10  [{'Overall': '4.6/5'}, {'Ease of Use': '4.5/5'...
# 11  [{'Overall': '4.5/5'}, {'Ease of Use': '4.7/5'...
# 12  [{'Overall': '4.4/5'}, {'Ease of Use': '4.5/5'...
#
#                                                Review
# 0   [[{'Fabio D.': ['Pedagogist', 'Education Manag...
# 1   [[{'Geoffrey L.': ['Nomad', 'Market Research, ...
# 2   [[{'Rashid C.': ['Teaching Assistant', 'Unspec...
# 3   [[{'Thomas Y.': ['Owner, previous CEO', 'Unspe...
# 4   [[{'Olga B.': ['Edutainment Coach', 'Education...
# 5   [[{'Omondi P.': ['Associate Programs Coordinat...
# 6   [[{'Cara C.': ['Project Manager', 'Events Serv...
# 7   [[{'Verified Reviewer': ['', 'Automotive, 10,0...
# 8   [[{'Shiva R.': ['Sr Director', 'Biotechnology,...
# 9   [[{'Cole P.': ['Marketing Director', 'Automoti...
# 10  [[{'Tom C.': ['Ecommerce Marketing', 'Health, ...
# 11  [[{'First Name N.': ['Associate', 'Investment ...
# 12  [[{'Lu Z.': ['Data analyst', 'Unspecified', 'U...

# %%
"""Creating a new dataframe with all the review info and product name & category"""
product_review = []
for i in range(len(product_review_df)):
    pro_name = product_review_df.iloc[i]['Product Name']
    pro_cat = product_review_df.iloc[i]['Category']
    pro_review = product_review_df.iloc[i]['Review']
    for j in pro_review:
        j.insert(0,pro_name)
        j.insert(1,pro_cat)
        product_review.append(j)

# %%
new_product_review_df = pd.DataFrame(product_review, columns=['Product Name', 'Category', 'Reviewer Info','Reviewer Ratings','Date', 'Review'])

# %%
new_product_review_df['Date'] = pd.to_datetime(new_product_review_df['Date'])

# %%
new_product_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      113 non-null    object
#  1   Category          113 non-null    object
#  2   Reviewer Info     113 non-null    object
#  3   Reviewer Ratings  113 non-null    object
#  4   Date              113 non-null    datetime64[ns]
#  5   Review            113 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 5.4+ KB

# %%
new_product_review_df_1 = new_product_review_df.groupby('Product Name')
Mozenda = new_product_review_df_1.get_group('Mozenda')
Mozenda
# Out:
#    Product Name               Category  \
# 2       Mozenda  data mining software
# 3       Mozenda  data mining software
# 4       Mozenda  data mining software
# 5       Mozenda  data mining software
# 6       Mozenda  data mining software
# 7       Mozenda  data mining software
# 8       Mozenda  data mining software
# 9       Mozenda  data mining software
# 10      Mozenda  data mining software
# 11      Mozenda  data mining software
# 12      Mozenda  data mining software
# 13      Mozenda  data mining software
# 14      Mozenda  data mining software
# 15      Mozenda  data mining software
# 16      Mozenda  data mining software
# 17      Mozenda  data mining software
# 18      Mozenda  data mining software
# 19      Mozenda  data mining software
# 20      Mozenda  data mining software
# 21      Mozenda  data mining software
# 22      Mozenda  data mining software
# 23      Mozenda  data mining software
# 24      Mozenda  data mining software
# 25      Mozenda  data mining software
# 26      Mozenda  data mining software
# 27      Mozenda  data mining software
# 28      Mozenda  data mining software
# 29      Mozenda  data mining software
# 30      Mozenda  data mining software
#
#                                         Reviewer Info  \
# 2   {'Geoffrey L.': ['Nomad', 'Market Research, 11...
# 3   {'Laurie K.': ['Data Analyst', 'Computer Softw...
# 4   {'Brian G.': ['Director', 'Computer Software, ...
# 5   {'Jon P.': ['Systems Engineer', 'Automotive, 1...
# 6   {'Pete P.': ['Customer Success Manager', 'Unsp...
# 7   {'Jim M.': ['Principal', 'Unspecified', 'Used ...
# 8   {'Jon P.': ['Partner', 'Information Technology...
# 9   {'Verified Reviewer': ['', '201-500 employees'...
# 10  {'Verified Reviewer': ['', 'Financial Services...
# 11  {'Michael M.': ['', 'Unspecified', 'Used the s...
# 12  {'Luca L.': ['CEO', 'Financial Services, 11-50...
# 13  {'Janne P.': ['Marketing manager', 'Retail, 11...
# 14  {'Winston K.': ['Director of Marketing', 'Elec...
# 15  {'Jeff S.': ['VP Product', 'Internet, 11-50 em...
# 16  {'Deb J.': ['Director', 'Unspecified', 'Used t...
# 17  {'Justin M.': ['Founder', 'Unspecified', 'Used...
# 18  {'lars f.': ['', 'Unspecified', 'Used the soft...
# 19  {'Sam G.': ['CEO', 'Fund-Raising, Self-employe...
# 20  {'steve l.': ['sales', 'Aviation & Aerospace, ...
# 21  {'Fraser T.': ['', 'Unspecified', 'Used the so...
# 22  {'Joe F.': ['Senior Developer', 'Unspecified',...
# 23  {'Jason G.': ['Software Engineer', 'Informatio...
# 24  {'Lauren R.': ['Marketing & Sales Support Assi...
# 25  {'Jon T.': ['Consultant', 'Unspecified', 'Used...
# 26  {'Valentina C.': ['Gerente de mercadeo', 'Mark...
# 27  {'Mark O.': ['', 'Unspecified', 'Used the soft...
# 28  {'Justin A.': ['', 'Unspecified', 'Used the so...
# 29  {'Tobias K.': ['Co-Founder', 'Wholesale, 11-50...
# 30  {'Patrick T.': ['Principal', 'Self-employed', ...
#
#                                      Reviewer Ratings       Date  \
# 2   [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2018-10-11
# 3   [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2020-09-20
# 4   [{'Overall': '3/5'}, {'Ease of Use': '2/5'}, {... 2020-11-01
# 5   [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2018-12-12
# 6   [{'Overall': '4/5'}, {'Ease of Use': '3/5'}, {... 2018-05-04
# 7   [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2016-04-20
# 8   [{'Overall': '4/5'}, {'Ease of Use': '3/5'}, {... 2016-11-08
# 9   [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2018-01-24
# 10  [{'Overall': '4/5'}, {'Ease of Use': '4/5'}, {... 2018-03-20
# 11  [{'Overall': '4/5'}, {'Ease of Use': '5/5'}, {... 2016-11-30
# 12  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2016-11-30
# 13  [{'Overall': '5/5'}, {'Ease of Use': '3/5'}, {... 2016-11-08
# 14  [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2016-11-08
# 15  [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2016-11-08
# 16  [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2016-02-02
# 17  [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2015-11-29
# 18  [{'Overall': '1/5'}, {'Ease of Use': '1/5'}, {... 2016-11-08
# 19  [{'Overall': '3/5'}, {'Ease of Use': '2/5'}, {... 2017-01-26
# 20  [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2016-12-05
# 21  [{'Overall': '5/5'}, {'Ease of Use': '4/5'}, {... 2016-12-09
# 22  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2014-01-16
# 23  [{'Overall': '1/5'}, {'Ease of Use': '1/5'}, {... 2018-03-15
# 24  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2019-01-21
# 25  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2010-01-21
# 26  [{'Overall': '3/5'}, {'Ease of Use': '4/5'}, {... 2019-03-26
# 27  [{'Overall': '5/5'}, {'Ease of Use': '3/5'}, {... 2016-11-30
# 28  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2016-11-08
# 29  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2019-08-20
# 30  [{'Overall': '5/5'}, {'Ease of Use': '5/5'}, {... 2016-11-30
#
#                                                Review
# 2   {'review heading': '“Ease of use”', 'Pros': 'I...
# 3   {'review heading': '“Well-supported scraping t...
# 4   {'review heading': '“Intentionally Burns Throu...
# 5   {'review heading': '“Mozenda efficiently scrap...
# 6   {'review heading': '“High-end web scraping too...
# 7   {'review heading': '“Enterprise class screen s...
# 8   {'review heading': '“Does what it should, reli...
# 9   {'review heading': '“Mozenda is my Secret Weap...
# 10  {'review heading': '“Knows no boundaries”', 'P...
# 11  {'review heading': '“Finally a robust web scra...
# 12  {'review heading': '“Best ever! ”', 'Overall':...
# 13  {'review heading': '“Setting up a new ecommerc...
# 14  {'review heading': '“Fast and easy”', 'Overall...
# 15  {'review heading': '“Great tool - provides a q...
# 16  {'review heading': '“I love this product.  It ...
# 17  {'review heading': '“Mozenda is a must for bus...
# 18  {'review heading': '“Not happy!”', 'Overall': ...
# 19  {'review heading': '“Steep learning curve...”'...
# 20  {'review heading': '“Pretty good software”', '...
# 21  {'review heading': '“Easy to use tool and amaz...
# 22  {'review heading': '“LongTime user loves this ...
# 23  {'review heading': '“The tool is fine for hobb...
# 24  {'review heading': '“Web Scraper ”', 'Pros': '...
# 25  {'review heading': '“Mozenda is it.  I have tr...
# 26  {'review heading': '“Data Capture”', 'Overall'...
# 27  {'review heading': '“You guys have always been...
# 28  {'review heading': '“Great product ”', 'Overal...
# 29  {'review heading': '“It works, but it's expens...
# 30  {'review heading': '“Amazing tool”', 'Overall'...
