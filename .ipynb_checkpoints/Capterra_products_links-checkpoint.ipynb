# %%
from selenium import webdriver 
from bs4 import BeautifulSoup
import pandas as pd   
import urllib  
import time
from timeit import default_timer as timer
import re

# %%
df  = pd.read_csv('capterra_categories.csv')

# %%
df.head()
# Out:
#                        Category Name  \
# 0      360 degree feedback software
# 1          3d architecture software
# 2                   3d cad software
# 3               ab testing software
# 4  account based marketing software
#
#                                        Category Link         Last Modified  \
# 0  https://www.capterra.com/360-degree-feedback-s...  2020-12-16T22:45:04Z
# 1  https://www.capterra.com/3d-architecture-softw...  2020-12-16T22:45:04Z
# 2          https://www.capterra.com/3d-cad-software/  2020-12-16T22:45:04Z
# 3      https://www.capterra.com/ab-testing-software/  2020-12-16T22:45:04Z
# 4  https://www.capterra.com/account-based-marketi...  2020-12-16T22:45:04Z
#
#   Change Frequency  Priority
# 0            daily       0.9
# 1            daily       0.9
# 2            daily       0.9
# 3            daily       0.9
# 4            daily       0.9

# %%
new = df.query('`Category Name`.str.startswith("data")')
new
# Out:
#                         Category Name  \
# 185           data analysis software
# 186  data center management software
# 187          data discovery software
# 188              data entry software
# 189         data extraction software
# 190         data governance software
# 191    data loss prevention software
# 192         data management software
# 193             data mining software
# 194            data quality software
# 195      data visualization software
# 196          data warehouse software
# 197     database management software
# 198     database monitoring software
#
#                                          Category Link         Last Modified  \
# 185   https://www.capterra.com/data-analysis-software/  2020-12-16T22:45:04Z
# 186  https://www.capterra.com/data-center-managemen...  2020-12-16T22:45:04Z
# 187  https://www.capterra.com/data-discovery-software/  2020-12-16T22:45:04Z
# 188      https://www.capterra.com/data-entry-software/  2020-12-16T22:45:04Z
# 189  https://www.capterra.com/data-extraction-softw...  2020-12-16T22:45:04Z
# 190  https://www.capterra.com/data-governance-softw...  2020-12-16T22:45:04Z
# 191  https://www.capterra.com/data-loss-prevention-...  2020-12-16T22:45:04Z
# 192  https://www.capterra.com/data-management-softw...  2020-12-16T22:45:04Z
# 193     https://www.capterra.com/data-mining-software/  2020-12-16T22:45:04Z
# 194    https://www.capterra.com/data-quality-software/  2020-12-16T22:45:04Z
# 195  https://www.capterra.com/data-visualization-so...  2020-12-16T22:45:04Z
# 196  https://www.capterra.com/data-warehouse-software/  2020-12-16T22:45:04Z
# 197  https://www.capterra.com/database-management-s...  2020-12-16T22:45:04Z
# 198  https://www.capterra.com/database-monitoring-s...  2020-12-16T22:45:04Z
#
#     Change Frequency  Priority
# 185            daily       0.9
# 186            daily       0.9
# 187            daily       0.9
# 188            daily       0.9
# 189            daily       0.9
# 190            daily       0.9
# 191            daily       0.9
# 192            daily       0.9
# 193            daily       0.9
# 194            daily       0.9
# 195            daily       0.9
# 196            daily       0.9
# 197            daily       0.9
# 198            daily       0.9

# %%
start = timer()

data = []
for i in range(len(new)):
    url = new.iloc[i]['Category Link']
    cat_name = new.iloc[i]['Category Name']
    
    driver = webdriver.Chrome(r'D:\Downloads\Desktop\chromedriver')
    driver.get(url)
    
    while True:
        try:
            button = driver.find_element_by_xpath('//button[normalize-space()="Show More"]')
            driver.execute_script("arguments[0].click();", button)
        except:
            break
    
    soup = BeautifulSoup(driver.page_source,"html.parser" )
    name = soup.find_all('div',{'class':'ProductCard__Root-sc-1aqkmbf-0 eiRAVe'})
    
    
    for i in name:
        no_reviews = i.find('div',{'class':'StarRating__Root-sc-1hocr1g-0 fuTecX'}).get_text(strip=True)[1]
        if no_reviews == "0": 
            product_name = i.find('span').get_text()
            category = cat_name
            company_name = i.find('h3',{'class':'VendorNameContainer__VendorHeading-sc-1ns38vc-0 klpzVA Heading-y0oiys-2 kdQRDY'}).get_text()[3:]
            url_to_capterra_page = "www.capterra.com" + str(i.find('a',{'target':'_self'}).get('href'))
            url_to_capterra_page = re.sub(r"reviews/",'', url_to_capterra_page)
            data.append([product_name,category,company_name,url_to_capterra_page])

    driver.close() 
    
    time.sleep(10)
    

end = timer()
time_taken = (end - start) 
print(time_taken)
# Out:
# 586.5026000480001

# %%
new_df = pd.DataFrame(data, columns=['Product Name', 'Category','Company Name','URL to Capterra Page'])
new_df
# Out:
#                   Product Name                       Category  \
# 0                       3Forge        data analysis software
# 1               ABEJA Platform        data analysis software
# 2         ABIS Analytics Cloud        data analysis software
# 3                        Ad2Go        data analysis software
# 4                    Alchemize        data analysis software
# ..                         ...                            ...
# 800              Opsview Cloud  database monitoring software
# 801                     Qualdo  database monitoring software
# 802                SQL Planner  database monitoring software
# 803  Sysgem Enterprise Manager  database monitoring software
# 804          Triotos IoT Suite  database monitoring software
#
#            Company Name                               URL to Capterra Page
# 0                3forge                  www.capterra.com/p/195802/3Forge/
# 1                 ABEJA          www.capterra.com/p/198306/ABEJA-Platform/
# 2         DBI Analytics    www.capterra.com/p/181385/ABIS-Analytics-Cloud/
# 3            ScanmarQED                   www.capterra.com/p/201253/Ad2Go/
# 4      Maxis Technology               www.capterra.com/p/185195/Alchemize/
# ..                  ...                                                ...
# 800             Opsview           www.capterra.com/p/196816/Opsview-Cloud/
# 801             Saturam                  www.capterra.com/p/202054/Qualdo/
# 802   WebSQL Technology             www.capterra.com/p/202210/SQL-Planner/
# 803              Sysgem  www.capterra.com/p/193643/Sysgem-Enterprise-Ma...
# 804             Triotos       www.capterra.com/p/208195/Triotos-IoT-Suite/
#
# [805 rows x 4 columns]

# %%
new_df.drop_duplicates('URL to Capterra Page')
new_df
# Out:
#                   Product Name                       Category  \
# 0                       3Forge        data analysis software
# 1               ABEJA Platform        data analysis software
# 2         ABIS Analytics Cloud        data analysis software
# 3                        Ad2Go        data analysis software
# 4                    Alchemize        data analysis software
# ..                         ...                            ...
# 800              Opsview Cloud  database monitoring software
# 801                     Qualdo  database monitoring software
# 802                SQL Planner  database monitoring software
# 803  Sysgem Enterprise Manager  database monitoring software
# 804          Triotos IoT Suite  database monitoring software
#
#            Company Name                               URL to Capterra Page
# 0                3forge                  www.capterra.com/p/195802/3Forge/
# 1                 ABEJA          www.capterra.com/p/198306/ABEJA-Platform/
# 2         DBI Analytics    www.capterra.com/p/181385/ABIS-Analytics-Cloud/
# 3            ScanmarQED                   www.capterra.com/p/201253/Ad2Go/
# 4      Maxis Technology               www.capterra.com/p/185195/Alchemize/
# ..                  ...                                                ...
# 800             Opsview           www.capterra.com/p/196816/Opsview-Cloud/
# 801             Saturam                  www.capterra.com/p/202054/Qualdo/
# 802   WebSQL Technology             www.capterra.com/p/202210/SQL-Planner/
# 803              Sysgem  www.capterra.com/p/193643/Sysgem-Enterprise-Ma...
# 804             Triotos       www.capterra.com/p/208195/Triotos-IoT-Suite/
#
# [805 rows x 4 columns]

# %%
new_df.to_csv('new_product_list.csv')
